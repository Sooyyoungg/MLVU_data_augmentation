# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
import glob
import xml.etree.ElementTree as Et
from xml.etree.ElementTree import Element, ElementTree
import pandas as pd

# %%
my_dict= {}
my_dict['aeroplane'] = 1
my_dict['bicycle'] = 2
my_dict['bird'] =3
my_dict['boat'] = 4
my_dict['bottle']= 5
my_dict['bus'] = 6
my_dict['car'] = 7
my_dict['cat'] = 8
my_dict['chair'] = 9
my_dict['cow'] = 10
my_dict['diningtable'] =11
my_dict['dog'] =12
my_dict['horse'] = 13
my_dict['motorbike'] = 14
my_dict['person'] = 15
my_dict['pottedplant'] =16
my_dict['sheep'] = 17
my_dict['sofa'] = 18
my_dict['train'] = 19
my_dict['tvmonitor'] = 20

# %%
xml_path = '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/*.xml'
file_list = glob.glob(xml_path)
print(len(file_list))
print(file_list)
# Out:
# 17125
# ['/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001764.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001904.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006384.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002831.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000756.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_002616.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004895.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2012_002303.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_003256.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001802.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2012_003165.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2012_002419.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004805.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_008550.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000557.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_003177.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001487.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002976.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000076.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001780.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004367.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2012_004111.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005817.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001086.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_005797.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_005660.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000466.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001937.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2012_001938.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_006150.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005989.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_005886.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_007153.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2012_001511.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002580.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004324.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001112.xml', '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2012_000748.xml', '/share/home/connectome/conmaster/MLVU/mmdetect ...

# %%
print("XML parsing Start\n")

py_dict = {}
for file_name in file_list:
    xml = open(file_name, "r")
    tree = Et.parse(xml)
    root = tree.getroot()

    segmented = root.find("segmented").text
    
    # if the image was segmented
    if segmented =='1':
        print(file_name)

        # find all of the objects in a xml file
        print("<Objects Description>")
        objects = root.findall("object")
        name_list= []
        for _object in objects:
            name = _object.find("name").text
            name_list.append(name)
        
        print("class : ", name_list)
        print("\n")    
        py_dict[file_name] = name_list
# Out:
# XML parsing Start
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001764.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004895.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004805.xml
# <Objects Description>
# class :  ['chair', 'sofa', 'tvmonitor']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_008550.xml
# <Objects Description>
# class :  ['sofa', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000466.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005989.xml
# <Objects Description>
# class :  ['motorbike', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001112.xml
# <Objects Description>
# class :  ['person', 'horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002147.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_002623.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_008476.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_003252.xml
# <Objects Description>
# class :  ['sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000391.xml
# <Objects Description>
# class :  ['pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002105.xml
# <Objects Description>
# class :  ['motorbike', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002378.xml
# <Objects Description>
# class :  ['person', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001632.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007392.xml
# <Objects Description>
# class :  ['horse', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_003872.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_003580.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002017.xml
# <Objects Description>
# class :  ['car', 'bottle', 'person', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_009331.xml
# <Objects Description>
# class :  ['horse', 'person', 'dog', 'dog', 'dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005647.xml
# <Objects Description>
# class :  ['sofa', 'sofa', 'chair', 'chair', 'chair', 'chair', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000444.xml
# <Objects Description>
# class :  ['tvmonitor', 'tvmonitor']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006660.xml
# <Objects Description>
# class :  ['car', 'boat', 'boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_004052.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001967.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007341.xml
# <Objects Description>
# class :  ['person', 'person', 'aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_002212.xml
# <Objects Description>
# class :  ['car', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_003511.xml
# <Objects Description>
# class :  ['dog', 'dog', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004056.xml
# <Objects Description>
# class :  ['bottle', 'bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002279.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_003711.xml
# <Objects Description>
# class :  ['car', 'bus', 'person', 'person', 'person', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000216.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_004712.xml
# <Objects Description>
# class :  ['person', 'diningtable', 'bottle', 'bottle', 'bottle', 'chair', 'chair', 'chair', 'chair', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_005085.xml
# <Objects Description>
# class :  ['car', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000277.xml
# <Objects Description>
# class :  ['train', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001640.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007003.xml
# <Objects Description>
# class :  ['bus', 'car', 'car', 'car', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003507.xml
# <Objects Description>
# class :  ['pottedplant', 'pottedplant', 'chair', 'chair', 'chair', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005791.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006151.xml
# <Objects Description>
# class :  ['horse', 'person', 'person', 'person', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004790.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007596.xml
# <Objects Description>
# class :  ['cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001010.xml
# <Objects Description>
# class :  ['cow', 'cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002137.xml
# <Objects Description>
# class :  ['cat', 'sofa', 'person', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004416.xml
# <Objects Description>
# class :  ['sofa']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005262.xml
# <Objects Description>
# class :  ['car', 'car', 'bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005419.xml
# <Objects Description>
# class :  ['dog', 'bottle', 'bottle', 'bottle', 'bottle', 'bottle', 'bottle', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_003453.xml
# <Objects Description>
# class :  ['car', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002845.xml
# <Objects Description>
# class :  ['sheep', 'sheep', 'sheep', 'sheep', 'sheep', 'sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_003271.xml
# <Objects Description>
# class :  ['bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002273.xml
# <Objects Description>
# class :  ['horse', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005718.xml
# <Objects Description>
# class :  ['car', 'car', 'aeroplane', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000801.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007084.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006641.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002902.xml
# <Objects Description>
# class :  ['car', 'car', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001601.xml
# <Objects Description>
# class :  ['sheep', 'sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003224.xml
# <Objects Description>
# class :  ['bicycle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002099.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_009597.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_003729.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001422.xml
# <Objects Description>
# class :  ['dog', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001350.xml
# <Objects Description>
# class :  ['sheep', 'sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000855.xml
# <Objects Description>
# class :  ['bus', 'bus', 'bus', 'bus', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002697.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_003593.xml
# <Objects Description>
# class :  ['sheep', 'sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_005445.xml
# <Objects Description>
# class :  ['tvmonitor', 'person', 'person', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006341.xml
# <Objects Description>
# class :  ['cat', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001732.xml
# <Objects Description>
# class :  ['bus', 'bus', 'car', 'car', 'bus', 'car', 'bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003773.xml
# <Objects Description>
# class :  ['cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001206.xml
# <Objects Description>
# class :  ['bus', 'person', 'bicycle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_009392.xml
# <Objects Description>
# class :  ['bus', 'car', 'car', 'car', 'car', 'car', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007428.xml
# <Objects Description>
# class :  ['motorbike', 'pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000002.xml
# <Objects Description>
# class :  ['sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002715.xml
# <Objects Description>
# class :  ['person', 'bicycle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004942.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002227.xml
# <Objects Description>
# class :  ['bus', 'person', 'person', 'person', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001341.xml
# <Objects Description>
# class :  ['bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_003813.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_003604.xml
# <Objects Description>
# class :  ['dog', 'tvmonitor']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005600.xml
# <Objects Description>
# class :  ['aeroplane', 'aeroplane', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000584.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_008051.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005166.xml
# <Objects Description>
# class :  ['cow', 'person', 'person', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_005231.xml
# <Objects Description>
# class :  ['bus', 'bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000505.xml
# <Objects Description>
# class :  ['pottedplant', 'person', 'person', 'person', 'sofa']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002845.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005836.xml
# <Objects Description>
# class :  ['car', 'car', 'car', 'car', 'motorbike']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000076.xml
# <Objects Description>
# class :  ['car', 'motorbike', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005844.xml
# <Objects Description>
# class :  ['chair', 'chair', 'chair', 'chair', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005368.xml
# <Objects Description>
# class :  ['bicycle', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_009419.xml
# <Objects Description>
# class :  ['pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_001724.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000112.xml
# <Objects Description>
# class :  ['bird', 'bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003810.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000187.xml
# <Objects Description>
# class :  ['bus', 'bus', 'bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_000799.xml
# <Objects Description>
# class :  ['horse', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006254.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005198.xml
# <Objects Description>
# class :  ['boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002447.xml
# <Objects Description>
# class :  ['sheep', 'sheep', 'sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001714.xml
# <Objects Description>
# class :  ['dog', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000022.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002638.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_001763.xml
# <Objects Description>
# class :  ['cat', 'dog', 'sofa', 'tvmonitor']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_005196.xml
# <Objects Description>
# class :  ['bus']
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_005716.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001139.xml
# <Objects Description>
# class :  ['bird', 'bird', 'chair', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001159.xml
# <Objects Description>
# class :  ['boat', 'boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000882.xml
# <Objects Description>
# class :  ['aeroplane', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004382.xml
# <Objects Description>
# class :  ['pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000924.xml
# <Objects Description>
# class :  ['sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_003651.xml
# <Objects Description>
# class :  ['pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000070.xml
# <Objects Description>
# class :  ['sofa']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004624.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007195.xml
# <Objects Description>
# class :  ['person', 'train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_003525.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003660.xml
# <Objects Description>
# class :  ['cat', 'cat', 'cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_008964.xml
# <Objects Description>
# class :  ['dog', 'dog', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001607.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_003180.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_003238.xml
# <Objects Description>
# class :  ['dog', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007250.xml
# <Objects Description>
# class :  ['bottle', 'tvmonitor']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000418.xml
# <Objects Description>
# class :  ['sofa', 'person', 'sofa', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001807.xml
# <Objects Description>
# class :  ['cow', 'boat', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002239.xml
# <Objects Description>
# class :  ['motorbike', 'person', 'car', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_005525.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_000491.xml
# <Objects Description>
# class :  ['cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005428.xml
# <Objects Description>
# class :  ['bird', 'bird', 'bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006216.xml
# <Objects Description>
# class :  ['aeroplane', 'person', 'person', 'person', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004112.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002376.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004643.xml
# <Objects Description>
# class :  ['motorbike', 'motorbike', 'motorbike', 'person', 'person', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002450.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000083.xml
# <Objects Description>
# class :  ['bicycle', 'person', 'bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001622.xml
# <Objects Description>
# class :  ['pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_002495.xml
# <Objects Description>
# class :  ['person', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002584.xml
# <Objects Description>
# class :  ['person', 'pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007994.xml
# <Objects Description>
# class :  ['bird', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000074.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007398.xml
# <Objects Description>
# class :  ['bus', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003736.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000758.xml
# <Objects Description>
# class :  ['cat', 'cat', 'cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_009759.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_003333.xml
# <Objects Description>
# class :  ['car', 'motorbike', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_002942.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004560.xml
# <Objects Description>
# class :  ['sheep', 'sheep', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_004081.xml
# <Objects Description>
# class :  ['cow', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004222.xml
# <Objects Description>
# class :  ['chair', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001997.xml
# <Objects Description>
# class :  ['tvmonitor', 'chair', 'tvmonitor', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001716.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000159.xml
# <Objects Description>
# class :  ['dog', 'dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_005217.xml
# <Objects Description>
# class :  ['pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000027.xml
# <Objects Description>
# class :  ['bottle', 'bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004345.xml
# <Objects Description>
# class :  ['motorbike']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000087.xml
# <Objects Description>
# class :  ['sofa']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005830.xml
# <Objects Description>
# class :  ['sofa', 'chair', 'person', 'person', 'person', 'person', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000628.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007098.xml
# <Objects Description>
# class :  ['cat', 'cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_002588.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000361.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002412.xml
# <Objects Description>
# class :  ['bird', 'bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004172.xml
# <Objects Description>
# class :  ['sofa']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006837.xml
# <Objects Description>
# class :  ['sheep', 'sheep', 'sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001261.xml
# <Objects Description>
# class :  ['diningtable', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000999.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001208.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000731.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004592.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_003238.xml
# <Objects Description>
# class :  ['person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001251.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_003503.xml
# <Objects Description>
# class :  ['car', 'car', 'bus', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000066.xml
# <Objects Description>
# class :  ['bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007902.xml
# <Objects Description>
# class :  ['motorbike', 'motorbike', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007534.xml
# <Objects Description>
# class :  ['sheep', 'sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006874.xml
# <Objects Description>
# class :  ['motorbike', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002426.xml
# <Objects Description>
# class :  ['person', 'sofa']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000712.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007120.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004322.xml
# <Objects Description>
# class :  ['cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000437.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007998.xml
# <Objects Description>
# class :  ['bottle', 'bottle', 'bottle', 'bottle', 'bottle', 'bottle', 'bottle', 'horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001529.xml
# <Objects Description>
# class :  ['bicycle', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000893.xml
# <Objects Description>
# class :  ['horse', 'horse', 'horse', 'horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_008392.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004226.xml
# <Objects Description>
# class :  ['sheep', 'sheep', 'sheep', 'sheep', 'sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006260.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004519.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001744.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000578.xml
# <Objects Description>
# class :  ['tvmonitor', 'person', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_003252.xml
# <Objects Description>
# class :  ['chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001478.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000213.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_003884.xml
# <Objects Description>
# class :  ['dog', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000567.xml
# <Objects Description>
# class :  ['pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001069.xml
# <Objects Description>
# class :  ['person', 'person', 'person', 'person', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_003781.xml
# <Objects Description>
# class :  ['cat', 'pottedplant', 'pottedplant', 'pottedplant', 'bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002295.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006219.xml
# <Objects Description>
# class :  ['horse', 'horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002763.xml
# <Objects Description>
# class :  ['motorbike']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004117.xml
# <Objects Description>
# class :  ['motorbike']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_003772.xml
# <Objects Description>
# class :  ['bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006066.xml
# <Objects Description>
# class :  ['sofa', 'chair', 'tvmonitor']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007402.xml
# <Objects Description>
# class :  ['diningtable', 'person', 'chair', 'chair', 'diningtable', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000843.xml
# <Objects Description>
# class :  ['bottle', 'chair', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005664.xml
# <Objects Description>
# class :  ['bicycle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_005544.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_003369.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007804.xml
# <Objects Description>
# class :  ['car', 'car', 'car', 'bus', 'car', 'car', 'car', 'car', 'car', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000673.xml
# <Objects Description>
# class :  ['person', 'chair', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001416.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007947.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002082.xml
# <Objects Description>
# class :  ['sheep', 'sheep']
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001413.xml
# <Objects Description>
# class :  ['aeroplane', 'car', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004621.xml
# <Objects Description>
# class :  ['sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004043.xml
# <Objects Description>
# class :  ['motorbike', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_008260.xml
# <Objects Description>
# class :  ['dog', 'sofa']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_005680.xml
# <Objects Description>
# class :  ['pottedplant', 'pottedplant', 'pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006605.xml
# <Objects Description>
# class :  ['chair', 'chair', 'chair', 'chair', 'chair', 'chair', 'pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001664.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001922.xml
# <Objects Description>
# class :  ['diningtable', 'pottedplant', 'chair', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005596.xml
# <Objects Description>
# class :  ['bus', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002286.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000589.xml
# <Objects Description>
# class :  ['sofa', 'sofa', 'sofa', 'sofa']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006877.xml
# <Objects Description>
# class :  ['boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_002697.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001232.xml
# <Objects Description>
# class :  ['cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_005189.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000409.xml
# <Objects Description>
# class :  ['horse', 'horse', 'horse', 'horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002228.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002083.xml
# <Objects Description>
# class :  ['sofa', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000682.xml
# <Objects Description>
# class :  ['bus', 'person', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004892.xml
# <Objects Description>
# class :  ['horse', 'horse', 'horse', 'horse', 'horse', 'horse', 'person', 'person', 'person', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002322.xml
# <Objects Description>
# class :  ['car', 'motorbike', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003369.xml
# <Objects Description>
# class :  ['dog', 'dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_004405.xml
# <Objects Description>
# class :  ['diningtable', 'chair', 'chair', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006873.xml
# <Objects Description>
# class :  ['bird', 'bird', 'bird', 'bird', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000809.xml
# <Objects Description>
# class :  ['chair', 'person', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_005628.xml
# <Objects Description>
# class :  ['boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007470.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_003841.xml
# <Objects Description>
# class :  ['cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002717.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005796.xml
# <Objects Description>
# class :  ['dog', 'cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000603.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004247.xml
# <Objects Description>
# class :  ['bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_003066.xml
# <Objects Description>
# class :  ['bottle', 'chair', 'chair', 'chair', 'chair', 'chair', 'chair', 'chair', 'chair', 'person', 'person', 'person', 'diningtable', 'diningtable', 'person', 'person', 'person', 'person', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_000830.xml
# <Objects Description>
# class :  ['diningtable', 'chair', 'chair', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007759.xml
# <Objects Description>
# class :  ['train', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000929.xml
# <Objects Description>
# class :  ['motorbike', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000795.xml
# <Objects Description>
# class :  ['person', 'person', 'person', 'bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003922.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003858.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_008511.xml
# <Objects Description>
# class :  ['motorbike', 'motorbike', 'motorbike', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005643.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000895.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000420.xml
# <Objects Description>
# class :  ['boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000426.xml
# <Objects Description>
# class :  ['bus', 'bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002929.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000469.xml
# <Objects Description>
# class :  ['person', 'person', 'bicycle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004993.xml
# <Objects Description>
# class :  ['sofa', 'tvmonitor']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000704.xml
# <Objects Description>
# class :  ['tvmonitor', 'tvmonitor', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002956.xml
# <Objects Description>
# class :  ['bus', 'bus', 'car', 'car', 'car', 'person', 'person', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000577.xml
# <Objects Description>
# class :  ['dog', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005469.xml
# <Objects Description>
# class :  ['sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001306.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001531.xml
# <Objects Description>
# class :  ['bicycle', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001448.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007548.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001830.xml
# <Objects Description>
# class :  ['bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000836.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001120.xml
# <Objects Description>
# class :  ['bird', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000931.xml
# <Objects Description>
# class :  ['horse', 'horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006063.xml
# <Objects Description>
# class :  ['cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002221.xml
# <Objects Description>
# class :  ['cow', 'cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000810.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_000733.xml
# <Objects Description>
# class :  ['person', 'motorbike']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000540.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_000629.xml
# <Objects Description>
# class :  ['train', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000919.xml
# <Objects Description>
# class :  ['boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000338.xml
# <Objects Description>
# class :  ['chair', 'chair', 'chair', 'diningtable', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002448.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002975.xml
# <Objects Description>
# class :  ['boat', 'boat', 'boat', 'boat', 'boat', 'boat', 'boat', 'boat', 'boat', 'boat', 'boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000566.xml
# <Objects Description>
# class :  ['cow', 'cow', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006008.xml
# <Objects Description>
# class :  ['chair', 'chair', 'chair', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002052.xml
# <Objects Description>
# class :  ['bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002539.xml
# <Objects Description>
# class :  ['bus', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002691.xml
# <Objects Description>
# class :  ['horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000392.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000512.xml
# <Objects Description>
# class :  ['motorbike', 'motorbike']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001400.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005805.xml
# <Objects Description>
# class :  ['cat', 'tvmonitor']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004339.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000666.xml
# <Objects Description>
# class :  ['horse', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004628.xml
# <Objects Description>
# class :  ['dog', 'dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_000836.xml
# <Objects Description>
# class :  ['person', 'horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_008927.xml
# <Objects Description>
# class :  ['cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000730.xml
# <Objects Description>
# class :  ['motorbike', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000162.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002462.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001336.xml
# <Objects Description>
# class :  ['diningtable', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005534.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007415.xml
# <Objects Description>
# class :  ['person', 'boat', 'person', 'person', 'person']
#
#
# ...
# <Objects Description>
# class :  ['aeroplane', 'bus', 'car', 'car', 'aeroplane', 'car', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005689.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_003134.xml
# <Objects Description>
# class :  ['person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004551.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001937.xml
# <Objects Description>
# class :  ['bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005318.xml
# <Objects Description>
# class :  ['car', 'person', 'person', 'person', 'person', 'person', 'person', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004654.xml
# <Objects Description>
# class :  ['bicycle', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_005031.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_003477.xml
# <Objects Description>
# class :  ['chair', 'chair', 'chair', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004748.xml
# <Objects Description>
# class :  ['car', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001828.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001515.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001231.xml
# <Objects Description>
# class :  ['person', 'bicycle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007651.xml
# <Objects Description>
# class :  ['person', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007523.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_008714.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001802.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000455.xml
# <Objects Description>
# class :  ['bus', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006784.xml
# <Objects Description>
# class :  ['sofa']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_004275.xml
# <Objects Description>
# class :  ['motorbike', 'person', 'pottedplant', 'pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004212.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002939.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001636.xml
# <Objects Description>
# class :  ['horse', 'horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001163.xml
# <Objects Description>
# class :  ['cow', 'cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002358.xml
# <Objects Description>
# class :  ['bottle', 'diningtable', 'person', 'person', 'person', 'person', 'person', 'chair', 'chair', 'chair', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002371.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004701.xml
# <Objects Description>
# class :  ['cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003991.xml
# <Objects Description>
# class :  ['chair', 'person', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002379.xml
# <Objects Description>
# class :  ['pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000987.xml
# <Objects Description>
# class :  ['person', 'tvmonitor']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_003846.xml
# <Objects Description>
# class :  ['car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_001079.xml
# <Objects Description>
# class :  ['sheep', 'sheep', 'sheep', 'sheep', 'sheep', 'sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000585.xml
# <Objects Description>
# class :  ['bicycle', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_002215.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000690.xml
# <Objects Description>
# class :  ['boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004635.xml
# <Objects Description>
# class :  ['boat', 'boat', 'boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000185.xml
# <Objects Description>
# class :  ['bird']
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000964.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000188.xml
# <Objects Description>
# class :  ['pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001972.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000454.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_003065.xml
# <Objects Description>
# class :  ['cow', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001076.xml
# <Objects Description>
# class :  ['person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002110.xml
# <Objects Description>
# class :  ['dog', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_001430.xml
# <Objects Description>
# class :  ['diningtable', 'person', 'person', 'person', 'pottedplant', 'tvmonitor', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006444.xml
# <Objects Description>
# class :  ['dog', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002528.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_004857.xml
# <Objects Description>
# class :  ['tvmonitor', 'tvmonitor']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005922.xml
# <Objects Description>
# class :  ['cow', 'cow', 'cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005111.xml
# <Objects Description>
# class :  ['bicycle', 'person', 'bottle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000219.xml
# <Objects Description>
# class :  ['cow', 'bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000074.xml
# <Objects Description>
# class :  ['motorbike', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000215.xml
# <Objects Description>
# class :  ['person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000724.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001607.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003164.xml
# <Objects Description>
# class :  ['bicycle', 'bicycle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_000549.xml
# <Objects Description>
# class :  ['cat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_005262.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_007143.xml
# <Objects Description>
# class :  ['boat', 'boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003696.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001895.xml
# <Objects Description>
# class :  ['sofa', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002427.xml
# <Objects Description>
# class :  ['sofa', 'sofa', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_001332.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007836.xml
# <Objects Description>
# class :  ['bicycle', 'bicycle', 'person', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000685.xml
# <Objects Description>
# class :  ['bicycle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000438.xml
# <Objects Description>
# class :  ['bottle', 'person', 'person', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004014.xml
# <Objects Description>
# class :  ['boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_001677.xml
# <Objects Description>
# class :  ['diningtable', 'chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_002244.xml
# <Objects Description>
# class :  ['bicycle', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_002411.xml
# <Objects Description>
# class :  ['horse', 'horse', 'person', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_003534.xml
# <Objects Description>
# class :  ['bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001924.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_000256.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_003188.xml
# <Objects Description>
# class :  ['bicycle', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_002010.xml
# <Objects Description>
# class :  ['car', 'dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006553.xml
# <Objects Description>
# class :  ['chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000790.xml
# <Objects Description>
# class :  ['aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002624.xml
# <Objects Description>
# class :  ['person', 'person', 'diningtable']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007810.xml
# <Objects Description>
# class :  ['diningtable', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_004358.xml
# <Objects Description>
# class :  ['train', 'train', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_002618.xml
# <Objects Description>
# class :  ['sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_001542.xml
# <Objects Description>
# class :  ['car', 'car']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_004829.xml
# <Objects Description>
# class :  ['bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_000938.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005813.xml
# <Objects Description>
# class :  ['pottedplant', 'pottedplant', 'pottedplant']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000422.xml
# <Objects Description>
# class :  ['dog']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007477.xml
# <Objects Description>
# class :  ['boat']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_000065.xml
# <Objects Description>
# class :  ['bicycle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005223.xml
# <Objects Description>
# class :  ['cow', 'cow', 'cow', 'cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_001288.xml
# <Objects Description>
# class :  ['aeroplane', 'aeroplane', 'aeroplane']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_007165.xml
# <Objects Description>
# class :  ['sheep', 'sheep']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_003634.xml
# <Objects Description>
# class :  ['chair']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_006076.xml
# <Objects Description>
# class :  ['bird', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_002047.xml
# <Objects Description>
# class :  ['cow']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_002383.xml
# <Objects Description>
# class :  ['motorbike']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2007_005304.xml
# <Objects Description>
# class :  ['bottle', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_006523.xml
# <Objects Description>
# class :  ['train']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2010_005106.xml
# <Objects Description>
# class :  ['aeroplane', 'person']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000982.xml
# <Objects Description>
# class :  ['horse', 'horse']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2009_003193.xml
# <Objects Description>
# class :  ['bicycle']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_001514.xml
# <Objects Description>
# class :  ['bird']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2008_000238.xml
# <Objects Description>
# class :  ['bus']
#
#
# /share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/Annotations/2011_000834.xml
# <Objects Description>
# class :  ['bird', 'bird', 'sheep', 'sheep', 'person', 'person', 'person', 'person', 'person']

# %%
empty = []
f = open("/share/home/connectome/conmaster/MLVU/Data/train_file.txt", 'r')
lines = f.readlines()
for line in lines:
    empty.append(line[:-1])
f.close()
print(len(empty))
print(empty)
# Out:
# 2185
# ['2007_000032', '2007_000033', '2007_000039', '2007_000042', '2007_000061', '2007_000063', '2007_000068', '2007_000121', '2007_000123', '2007_000129', '2007_000170', '2007_000175', '2007_000187', '2007_000241', '2007_000243', '2007_000250', '2007_000256', '2007_000323', '2007_000332', '2007_000333', '2007_000346', '2007_000363', '2007_000364', '2007_000392', '2007_000452', '2007_000464', '2007_000480', '2007_000491', '2007_000504', '2007_000515', '2007_000528', '2007_000529', '2007_000549', '2007_000559', '2007_000572', '2007_000584', '2007_000629', '2007_000636', '2007_000645', '2007_000648', '2007_000661', '2007_000663', '2007_000676', '2007_000713', '2007_000720', '2007_000727', '2007_000733', '2007_000738', '2007_000762', '2007_000768', '2007_000783', '2007_000793', '2007_000799', '2007_000804', '2007_000822', '2007_000830', '2007_000836', '2007_000837', '2007_000847', '2007_000862', '2007_000876', '2007_000904', '2007_000925', '2007_000999', '2007_001027', '2007_001073', '2007_001149', '2007_001154', '2007_001175', '2007_001185', '2007_001225', '2007_001239', '2007_001284', '2007_001288', '2007_001289', '2007_001299', '2007_001311', '2007_001321', '2007_001340', '2007_001377', '2007_001397', '2007_001408', '2007_001416', '2007_001420', '2007_001423', '2007_001430', '2007_001439', '2007_001457', '2007_001458', '2007_001487', '2007_001526', '2007_001568', '2007_001585', '2007_001586', '2007_001587', '2007_001594', '2007_001595', '2007_001602', '2007_001609', '2007_001630', '2007_001677', '2007_001678', '2007_001698', '2007_001704', '2007_001709', '2007_001717', '2007_001724', '2007_001733', '2007_001761', '2007_001763', '2007_001764', '2007_001774', '2007_001825', '2007_001834', '2007_001857', '2007_001872', '2007_001884', '2007_001901', '2007_001917', '2007_001955', '2007_001960', '2007_002024', '2007_002046', '2007_002055', '2007_002088', '2007_002094', '2007_002099', '2007_002105', '2007_002107', '2007_002119', '2007_002120', '2007_002132', '2007_002142', '2007_002198', '2007_002212', '2007_002216', '2007_002227', '2007_002234', '2007_002260', '2007_002266', '2007_002268', '2007_002273', '2007_002281', '2007_002284', '2007_002293', '2007_002361', '2007_002368', '2007_002370', '2007_002376', '2007_002378', '2007_002387', '2007_002400', '2007_002403', '2007_002412', '2007_002426', '2007_002427', '2007_002445', '2007_002462', '2007_002470', '2007_002488', '2007_002539', '2007_002545', '2007_002565', '2007_002597', '2007_002611', '2007_002618', '2007_002619', '2007_002624', '2007_002639', '2007_002643', '2007_002648', '2007_002668', '2007_002669', '2007_002719', '2007_002728', '2007_002760', '2007_002789', '2007_002823', '2007_002824', '2007_002845', '2007_002852', '2007_002895', '2007_002896', '2007_002903', '2007_002914', '2007_002953', '2007_002954', '2007_002967', '2007_003000', '2007_003011', '2007_003020', '2007_003022', '2007_003051', '2007_003088', '2007_003101', '2007_003106', '2007_003110', '2007_003118', '2007_003131', '2007_003134', '2007_003137', '2007_003143', '2007_003169', '2007_003178', '2007_003188', '2007_003189', '2007_003190', '2007_003191', '2007_003194', '2007_003195', '2007_003201', '2007_003205', '2007_003207', '2007_003251', '2007_003267', '2007_003286', '2007_003330', '2007_003349', '2007_003367', '2007_003373', '2007_003431', '2007_003451', '2007_003499', '2007_003503', '2007_003506', '2007_003525', '2007_003529', '2007_003530', '2007_003541', '2007_003565', '2007_003571', '2007_003580', '2007_003587', '2007_003593', '2007_003604', '2007_003611', '2007_003621', '2007_003668', '2007_003682', '2007_003711', '2007_003714', '2007_003715', '2007_003742', '2007_003778', '2007_003786', '2007_003788', '2007_003815', '2007_003841', '2007_003848', '2007_003861', '2007_003872', '2007_003876', '2007_003889', '2007_003910', '2007_003917', '2007_003957', '2007_003991', '2007_004003', '2007_004009', '2007_004033', '2007_004052', '2007_004065', '2007_004081', '2007_004112', '2007_004121', '2007_004143', '2007_004 ...

# %%
img_path = '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/JPEGImages/'
seg_path = '/share/home/connectome/conmaster/MLVU/mmdetection/data/VOCdevkit/VOC2012/SegmentationClass/'

# %%
stat_dist=np.zeros([20, 20], dtype=int)

distribution=pd.DataFrame(stat_dist, columns=my_dict.keys(), index=my_dict.keys())
print(distribution)
# Out:
#              aeroplane  bicycle  bird  boat  bottle  bus  car  cat  chair  \
# aeroplane            0        0     0     0       0    0    0    0      0
# bicycle              0        0     0     0       0    0    0    0      0
# bird                 0        0     0     0       0    0    0    0      0
# boat                 0        0     0     0       0    0    0    0      0
# bottle               0        0     0     0       0    0    0    0      0
# bus                  0        0     0     0       0    0    0    0      0
# car                  0        0     0     0       0    0    0    0      0
# cat                  0        0     0     0       0    0    0    0      0
# chair                0        0     0     0       0    0    0    0      0
# cow                  0        0     0     0       0    0    0    0      0
# diningtable          0        0     0     0       0    0    0    0      0
# dog                  0        0     0     0       0    0    0    0      0
# horse                0        0     0     0       0    0    0    0      0
# motorbike            0        0     0     0       0    0    0    0      0
# person               0        0     0     0       0    0    0    0      0
# pottedplant          0        0     0     0       0    0    0    0      0
# sheep                0        0     0     0       0    0    0    0      0
# sofa                 0        0     0     0       0    0    0    0      0
# train                0        0     0     0       0    0    0    0      0
# tvmonitor            0        0     0     0       0    0    0    0      0
#
#              cow  diningtable  dog  horse  motorbike  person  pottedplant  \
# aeroplane      0            0    0      0          0       0            0
# bicycle        0            0    0      0          0       0            0
# bird           0            0    0      0          0       0            0
# boat           0            0    0      0          0       0            0
# bottle         0            0    0      0          0       0            0
# bus            0            0    0      0          0       0            0
# car            0            0    0      0          0       0            0
# cat            0            0    0      0          0       0            0
# chair          0            0    0      0          0       0            0
# cow            0            0    0      0          0       0            0
# diningtable    0            0    0      0          0       0            0
# dog            0            0    0      0          0       0            0
# horse          0            0    0      0          0       0            0
# motorbike      0            0    0      0          0       0            0
# person         0            0    0      0          0       0            0
# pottedplant    0            0    0      0          0       0            0
# sheep          0            0    0      0          0       0            0
# sofa           0            0    0      0          0       0            0
# train          0            0    0      0          0       0            0
# tvmonitor      0            0    0      0          0       0            0
#
#              sheep  sofa  train  tvmonitor
# aeroplane        0     0      0          0
# bicycle          0     0      0          0
# bird             0     0      0          0
# boat             0     0      0          0
# bottle           0     0      0          0
# bus              0     0      0          0
# car              0     0      0          0
# cat              0     0      0          0
# chair            0     0      0          0
# cow              0     0      0          0
# diningtable      0     0      0          0
# dog              0     0      0          0
# horse            0     0      0          0
# motorbike        0     0      0          0
# person           0     0      0          0
# pottedplant      0     0      0          0
# sheep            0     0      0          0
# sofa             0     0      0          0
# train            0     0      0          0
# tvmonitor        0     0      0          0

# %%
# 이런 식으로 호출해서 값 추가할 예정
distribution['car']['sheep']
# Out:
# 0

# %%
"""count the number of appearence of each object when two or more objects """
count_iso=np.zeros([1,20], dtype=int)
count_iso=pd.DataFrame(count_iso, columns=my_dict.keys())

# for all images
for key in py_dict.keys():
    image_name = key[-15:-4]
    
    # if image is in dataset
    if str(image_name) in empty:
        objects=py_dict[key]
        
        if len(objects) > 1:
            # add value of two objects in one image to distribution matrix
            for obj in objects:
                for other_objs in objects:
                    # Isomorphic matrix
                    distribution[obj][other_objs] += 1
                distribution[obj][obj] -= 1

# %%
distribution
# Out:
#              aeroplane  bicycle  bird  boat  bottle  bus  car  cat  chair  \
# aeroplane           78        0     0     1       0    6   16    0      0
# bicycle              0      156     0     0       5    5   29    2      8
# bird                 0        0   150     6       0    0    6    0      0
# boat                 1        0     6   230       0    4   17    0      0
# bottle               0        5     0     0     670    1    8    4     56
# bus                  6        5     0     4       1  240  106    0      0
# car                 16       29     6    17       8  106  614    1      1
# cat                  0        2     0     0       4    0    1   80     11
# chair                0        8     0     0      56    0    1   11    804
# cow                  0        0     0     1       0    0   33    1      0
# diningtable          0        0     0     0      47    0    1    4    207
# dog                  0        0     0     0       0    0   13    5     23
# horse                0        0     0     0       7    0    4    0      3
# motorbike            0        0     0     1       1    1   40    0      4
# person              57      275    23    66     239   92  359   16    210
# pottedplant          0       10     3     0      23    0    5   12     91
# sheep                0        0     0     0       2    0    6    0      0
# sofa                 0        7     0     0       7    0    1   13    104
# train                0        0     0     0       0    0    5    0      0
# tvmonitor            0        9     1     0      32    0    4    5     71
#
#              cow  diningtable  dog  horse  motorbike  person  pottedplant  \
# aeroplane      0            0    0      0          0      57            0
# bicycle        0            0    0      0          0     275           10
# bird           0            0    0      0          0      23            3
# boat           1            0    0      0          1      66            0
# bottle         0           47    0      7          1     239           23
# bus            0            0    0      0          1      92            0
# car           33            1   13      4         40     359            5
# cat            1            4    5      0          0      16           12
# chair          0          207   23      3          4     210           91
# cow          424            0    0      8          0      95            1
# diningtable    0           14    2      0          0     176           20
# dog            0            2  112      4          2      78            3
# horse          8            0    4    128          0     136            4
# motorbike      0            0    2      0        112     251           10
# person        95          176   78    136        251    2962          123
# pottedplant    1           20    3      4         10     123          494
# sheep          0            0    7      8          0      54            0
# sofa           0           17   18      0          1      58           35
# train          0            0    0      0          0      33            2
# tvmonitor      0            8    3      0          0     107           12
#
#              sheep  sofa  train  tvmonitor
# aeroplane        0     0      0          0
# bicycle          0     7      0          9
# bird             0     0      0          1
# boat             0     0      0          0
# bottle           2     7      0         32
# bus              0     0      0          0
# car              6     1      5          4
# cat              0    13      0          5
# chair            0   104      0         71
# cow              0     0      0          0
# diningtable      0    17      0          8
# dog              7    18      0          3
# horse            8     0      0          0
# motorbike        0     1      0          0
# person          54    58     33        107
# pottedplant      0    35      2         12
# sheep          904     0      0          0
# sofa             0    52      0         28
# train            0     0     42          0
# tvmonitor        0    28      0         90

# %%
distribution.shape
# Out:
# (20, 20)

# %%
############ Training ############
"""make training data"""
## Image
# 1. Image -> numpy array
# 2. concatenate 3 channel original images and 1 channel segmentation annotation
# 3. resize to unify the sizes of input images
# 4. stack all the image information

## Class
# 1. make an array for each image : 1 x 20
# 2. count the number of detection for each objects
# 3. resize for stacking
# 4. normalize the arraies to make their sum is 1
# 5. stack all the class information

X=[]
Y=[]
count=0
for key in py_dict.keys():
    image_name = key[-15:-4]
    
    # if image is in dataset
    if str(image_name) in empty:
        
        """ Input Data """
        # get segment informations by pixel
        segmentation_path = seg_path + image_name + '.png'
        seg_image = Image.open(segmentation_path)
        array_pixel = np.array(seg_image)

        # get original images information by pixel
        image_path  = img_path + image_name + '.jpg'
        image = Image.open(image_path)
        image_pixel = np.array(image)
                
        # concatenate original image and segmentation annotation
        input_image = np.dstack((image_pixel, array_pixel))
        
        # resize the input images as the sizes of the images are different
        input_image=np.resize(input_image, (1, 500, 500, 4))
        
        # stack all the input images
        if count==0:
            X = input_image
        else:
            X = np.concatenate((X, input_image), axis=0)
        
        """ Label=Class data """
        input_class=np.zeros(20, dtype=float)
        for obj in py_dict[key]:
            input_class[my_dict[obj]-1]+=1
        input_class = np.resize(input_class, (1, 20))
        
        # normalize the values whose sum has to be 1
        T = np.copy(input_class)
        for i in range(len(my_dict.keys())):
            sums = input_class[0].sum()
            T[0][i] /= float(sums)
        
        # stack all the class informations
        if count==0:
            Y = T
            count+=1
        else:
            Y = np.concatenate((Y, T), axis=0)
        
X_train=np.array(X)
Y_train=np.array(Y)
print(X_train.shape)
print(Y_train.shape)
# Out:
# (2185, 500, 500, 4)
# (2185, 20)

# %%
distribution.to_csv("./distribution.csv", index=False)
np.save('./X_train', X_train)
np.save("./Y_train", Y_train)
